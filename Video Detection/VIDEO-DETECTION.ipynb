# %% [markdown]
# # **DETECÇÃO DE OBJETOS EM VIDEOS - DETECÇÃO E SEGMENTAÇÃO**
# ## ***INTEGRANTES:*** ##
# *Maurício Vieira Pereira - RM553748*
# *Yago Lucas Golçalves da Silva - RM553013*

# %% [markdown]
# # **DETECÇÃO DE OBJETOS EM VIDEOS**
# #### **YOLOv8 - DETECÇÃO**
# Nesse modelo estamos utilizando o YOLOv8 para realizar a detecção de objetos em vídeos. O modelo foi treinado com o dataset COCO e possui 80 classes de objetos.
# A task de detecção é realizada através dos comandos abaixo, onde é passado o modelo, a confiança e a imagem de entrada.
# Vamos fazer a comparação entre o modelo YOLOv8n e YOLOv8m, utilizando os pesos pré-treinados para a detecção de objetos em vídeos.

# %%
# Instalando a biblioteca do YOLOv8
# !pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importando o pacote ultralytics
import ultralytics

# Importando o pacote Pytorch
import torch

# Importando as demais bibliotecas
import cv2
import matplotlib.pyplot as plt
import os
from PIL import Image

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.75 source='videos/video1.mp4' save=False
# Out:
# Ultralytics YOLOv8.2.92 🚀 Python-3.11.5 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (frame 1/504) c:\Users\caver\OneDrive\Área de Trabalho\COLLEGE PROJECTS 2024 - 2 SEM\IA\CP01-DISRUPTIVE-AI\Video Detection\videos\video1.mp4: 640x640 2 persons, 173.1ms
# video 1/1 (frame 2/504) c:\Users\caver\OneDrive\Área de Trabalho\COLLEGE PROJECTS 2024 - 2 SEM\IA\CP01-DISRUPTIVE-AI\Video Detection\videos\video1.mp4: 640x640 2 persons, 124.0ms
# video 1/1 (frame 3/504) c:\Users\caver\OneDrive\Área de Trabalho\COLLEGE PROJECTS 2024 - 2 SEM\IA\CP01-DISRUPTIVE-AI\Video Detection\videos\video1.mp4: 640x640 2 persons, 137.4ms
# video 1/1 (frame 4/504) c:\Users\caver\OneDrive\Área de Trabalho\COLLEGE PROJECTS 2024 - 2 SEM\IA\CP01-DISRUPTIVE-AI\Video Detection\videos\video1.mp4: 640x640 2 persons, 145.1ms
# ...

# %%
# !yolo task=detect mode=predict model=yolov8m.pt conf=0.75 source='videos/video1.mp4' save=False
# Out:
# ...
#   0%|          | 0.00/49.7M [00:00<?, ?B/s]
#   1%|▏         | 640k/49.7M [00:00<00:08, 6.38MB/s]
#   4%|▎         | 1.75M/49.7M [00:00<00:09, 5.42MB/s]
#   5%|▍         | 2.38M/49.7M [00:00<00:13, 3.63MB/s]
#   6%|▌         | 3.00M/49.7M [00:00<00:12, 3.90MB/s]
#   7%|▋         | 3.62M/49.7M [00:00<00:10, 4.45MB/s]
#   9%|▊         | 4.25M/49.7M [00:00<00:10, 4.65MB/s]
#  11%|█         | 5.25M/49.7M [00:01<00:07, 6.04MB/s]
#  12%|█▏        | 6.00M/49.7M [00:01<00:11, 3.99MB/s]
#  13%|█▎        | 6.62M/49.7M [00:01<00:14, 3.20MB/s]
#  16%|█▌        | 7.75M/49.7M [00:02<00:13, 3.25MB/s]
#  18%|█▊        | 8.75M/49.7M [00:02<00:10, 4.24MB/s]
#  19%|█▉        | 9.38M/49.7M [00:02<00:12, 3.45MB/s]
#  20%|█▉        | 9.88M/49.7M [00:02<00:14, 2.86MB/s]
#  22%|██▏       | 11.0M/49.7M [00:03<00:13, 3.02MB/s]
#  24%|██▍       | 12.1M/49.7M [00:03<00:12, 3.16MB/s]
#  26%|██▋       | 13.1M/49.7M [00:03<00:12, 3.14MB/s]
#  29%|██▊       | 14.2M/49.7M [00:04<00:11, 3.25MB/s]
# ...

# %% [markdown]
# ### Se estiver utilizando o VSCode, execute os 3 nódulos abaixo para exibir o vídeo. (LEMBRE-SE DE AJUSTAR OS CAMINHOS)

# %%
# Nódulo 1
# Instalando as bibliotecas necessárias

# !pip install imageio
# !pip install imageio[ffmpeg]
# !pip install imageio-ffmpeg
import imageio

import imageio
from tkinter import Tk, Label
from PIL import Image, ImageTk
import threading
 
def exibir_video_vscode(video_caminho):
    # Carrega o vídeo usando o backend ffmpeg
    video = imageio.get_reader(video_caminho, 'ffmpeg')
    root = Tk()
    lbl = Label(root)
    lbl.pack()
 
    def stream():
        try:
            for frame in video.iter_data():
                img = ImageTk.PhotoImage(Image.fromarray(frame))
                lbl.config(image=img)
                lbl.image = img  # Atualiza a imagem no widget
                root.update()
        except RuntimeError:
            pass
 
    # Rodar o vídeo em uma thread separada para evitar congelamento
    threading.Thread(target=stream).start()
    root.mainloop()
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Nódulo 2
exibir_video_vscode('runs/detect/predict/video1.mp4')

# %%
# Nódulo 3
exibir_video_vscode('runs/detect/predict2/video1.mp4')

# %% [markdown]
# ### Se estiver utilizando o Jupyter Notebook, execute os 3 nódulo abaixo para exibir o vídeo. (LEMBRE-SE DE AJUSTAR OS CAMINHOS)

# %%
# Nódulo 1
def exibir_video_jupyter(video_caminho):
  from IPython.display import HTML
  from base64 import b64encode
  mp4 = open(video_caminho, 'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=500 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
# Nódulo 2
exibir_video_jupyter('runs/detect/predict/video1.mp4')

# %%
# Nódulo 3
exibir_video_jupyter('runs/detect/predict2/video1.mp4')

# %% [markdown]
# ### **Resultados Obtidos**
# O modelo YOLOv8m obteve um resultado superior ao modelo YOLOv8n, com uma melhor detecção dos objetos presentes no vídeo.
# O modelo YOLOv8n detectou apenas 2 objetos durante o vídeo, sendo eles pessoas e laptops, enquanto o modelo YOLOv8m detectou 4 objetos, sendo eles pessoas, laptops, canecas e livros.
#
# ##### Obs.: A opção 'save=True' foi alterada para 'save=False' para que a imagem não seja salva no diretório, já que o código ja foi executado e as imagens estão salvas no diretório.

# %% [markdown]
# # **SEGMENTAÇÃO DE OBJETOS EM VIDEOS**
# #### **YOLOv8 - SEGMENTAÇÃO**
# Nesse modelo estamos utilizando o YOLOv8 para realizar a segmentação de objetos em vídeos. O modelo foi treinado com o dataset COCO e possui 80 classes de objetos.
# A task de segmentação é realizada através do comando abaixo, onde é passado o modelo, a confiança e a imagem de entrada.
# Vamos fazer a comparação entre o modelo YOLOv8n e YOLOv8m, utilizando os pesos pré-treinados para a segmentação de objetos em vídeos.

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt conf=0.75 source='videos/video2.mp4' save=False
# Out:
# ...
# Ultralytics YOLOv8.2.92 🚀 Python-3.11.5 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# video 1/1 (frame 1/300) c:\Users\caver\OneDrive\Área de Trabalho\COLLEGE PROJECTS 2024 - 2 SEM\IA\CP01-DISRUPTIVE-AI\Video Detection\videos\video2.mp4: 640x640 4 persons, 1 car, 1 bus, 1053.0ms
# video 1/1 (frame 2/300) c:\Users\caver\OneDrive\Área de Trabalho\COLLEGE PROJECTS 2024 - 2 SEM\IA\CP01-DISRUPTIVE-AI\Video Detection\videos\video2.mp4: 640x640 4 persons, 1 car, 1 bus, 1723.6ms
# video 1/1 (frame 3/300) c:\Users\caver\OneDrive\Área de Trabalho\COLLEGE PROJECTS 2024 - 2 SEM\IA\CP01-DISRUPTIVE-AI\Video Detection\videos\video2.mp4: 640x640 4 persons, 1 car, 1 bus, 503.3ms
# video 1/1 (frame 4/300) c:\Users\caver\OneDrive\Área de Trabalho\COLLEGE PROJECTS 2024 - 2 SEM\IA\CP01-DISRUPTIVE-AI\Video Detection\videos\video2.mp4: 640x640 4 persons, 1 car, 1 bus, 513.4ms
# ...

# %%
# !yolo task=segment mode=predict model=yolov8m-seg.pt conf=0.75 source='videos/video2.mp4' save=False
# Out:
# Ultralytics YOLOv8.2.92 🚀 Python-3.11.5 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# YOLOv8m-seg summary (fused): 245 layers, 27,268,704 parameters, 0 gradients, 110.2 GFLOPs
#
# video 1/1 (frame 1/300) c:\Users\caver\OneDrive\Área de Trabalho\COLLEGE PROJECTS 2024 - 2 SEM\IA\CP01-DISRUPTIVE-AI\Video Detection\videos\video2.mp4: 640x640 4 persons, 1 car, 1 bus, 1 handbag, 1547.4ms
# video 1/1 (frame 2/300) c:\Users\caver\OneDrive\Área de Trabalho\COLLEGE PROJECTS 2024 - 2 SEM\IA\CP01-DISRUPTIVE-AI\Video Detection\videos\video2.mp4: 640x640 4 persons, 1 car, 1 bus, 1 handbag, 875.4ms
# video 1/1 (frame 3/300) c:\Users\caver\OneDrive\Área de Trabalho\COLLEGE PROJECTS 2024 - 2 SEM\IA\CP01-DISRUPTIVE-AI\Video Detection\videos\video2.mp4: 640x640 4 persons, 1 car, 1 bus, 1 handbag, 750.7ms
# ...

# %% [markdown]
# ### Se estiver utilizando o VSCode, execute os 3 nódulos abaixo para exibir o vídeo. (LEMBRE-SE DE AJUSTAR OS CAMINHOS)

# %%
# Nódulo 1
# Instalando as bibliotecas necessárias

# !pip install imageio
# !pip install imageio[ffmpeg]
# !pip install imageio-ffmpeg
import imageio

import imageio
from tkinter import Tk, Label
from PIL import Image, ImageTk
import threading
 
def exibir_video_vscode(video_caminho):
    # Carrega o vídeo usando o backend ffmpeg
    video = imageio.get_reader(video_caminho, 'ffmpeg')
    root = Tk()
    lbl = Label(root)
    lbl.pack()
 
    def stream():
        try:
            for frame in video.iter_data():
                img = ImageTk.PhotoImage(Image.fromarray(frame))
                lbl.config(image=img)
                lbl.image = img  # Atualiza a imagem no widget
                root.update()
        except RuntimeError:
            pass
 
    # Rodar o vídeo em uma thread separada para evitar congelamento
    threading.Thread(target=stream).start()
    root.mainloop()

# %%
# Nódulo 2
exibir_video_vscode('runs/segment/predict/video2.mp4')

# %%
# Nódulo 3
exibir_video_vscode('runs/segment/predict2/video2.mp4')

# %% [markdown]
# ### Se estiver utilizando o Jupyter Notebook, execute os 3 nódulo abaixo para exibir o vídeo. (LEMBRE-SE DE AJUSTAR OS CAMINHOS)

# %%
# Nódulo 1
def exibir_video_jupyter(video_caminho):
  from IPython.display import HTML
  from base64 import b64encode
  mp4 = open(video_caminho, 'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=500 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
# Nódulo 2
exibir_video_jupyter('runs/segment/predict/video2.mp4')

# %%
# Nódulo 3
exibir_video_jupyter('runs/segment/predict2/video2.mp4')

# %% [markdown]
# ### **Resultados Obtidos**
# O modelo YOLOv8m obteve um resultado superior ao modelo YOLOv8n, com uma melhor detecção dos objetos presentes no vídeo.
# O modelo YOLOv8n detectou 6 objetos durante o video sendo eles pessoas, onibus, carro, mala, semaforo e bolsa de mão. Já o modelo YOLOv8m detectou 7 objetos, sendo eles pessoas, onibus, carro, mala, semaforo, bolsa de mão e mochila.
# Apesar de ambos os modelos terem detectado os mesmo objetos, o modelo YOLOv8m conseguiu detectar um objeto a mais, que foi a mochila, além de ter detectado os objetos com mais precisão e mais vezes durante o vídeo.
#
# ##### Obs.: A opção 'save=True' foi alterada para 'save=False' para que a imagem não seja salva no diretório, já que o código ja foi executado e as imagens estão salvas no diretório.
